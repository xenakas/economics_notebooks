# %% [markdown]
# ##  Модели с дискретными объясняемыми переменными

# %% [markdown]
# ####    1. Как модель бинарного выбора линейной моделью для некоторой ненаблюдаемой переменной? Какие проблемы возникают при попытке оценивания коэффициентов этой линейной модели?

# %% [markdown]
# ####    2. Показатели качества моделей бинарного выбора, критерии согласия с имеющимися данными, сравнение альтернативных моделей.

# %% [markdown]
# ####    3. Как интерпретируются  коэффициенты в моделях бинарного выбора?

# %% [markdown]
# ####    4. Как проверяется выполнение стандартных предположений в моделях бинарного выбора?

# %% [markdown]
# ####    5. В  чем состоит порядковая пробит-модель и как она оценивается?

# %% [markdown]
# ####    6. Какие модели используются в ситуациях, когда не существует естественного упорядочения K альтернатив, среди которых производится выбор?

# %% [markdown]
# ####    7. В чем состоит модель Tobit  и как она оценивается? Как интерпретируются результаты оценивания?

# %% [markdown]
# ####    8. Что представляет собой модель Tobit-II  и как она оценивается? В чем состоит процедура Хекмана?
